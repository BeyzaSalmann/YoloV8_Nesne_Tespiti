# %% [markdown]
# Adınız: Beyza
#
# Soyadınız: Salman
#
# Okul Numaranız: 2212721049
#
# GitHub Repo Bağlantısı: https://github.com/BeyzaSalmann/YoloV8_Nesne_Tespiti

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="msMSdRMH2ZH7R2NLZ3o9")
project = rf.workspace("unokarttespitiodev").project("uno-2xna0")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 plots=True workers=1
# Out:
# ...
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import os
from google.colab import files

print(" Dosya aranıyor, lütfen bekleyin...")

dosya_yolu = None
for root, dirs, files_list in os.walk('/content'):
    if 'best.pt' in files_list:
        dosya_yolu = os.path.join(root, 'best.pt')
        print(f" BULDUM! Dosya burada saklanıyormuş: {dosya_yolu}")
        break

if dosya_yolu:
    print(" İndirme başlatılıyor...")
    files.download(dosya_yolu)
else:
    print(" Dosya bulunamadı. Eğitim hata vermiş veya tamamlanmamış olabilir.")

    print("\n Mevcut Klasör Yapısı:")
    os.system("ls -R")
# Out:
#  Dosya aranıyor, lütfen bekleyin...
#  BULDUM! Dosya burada saklanıyormuş: /content/runs/detect/train/weights/best.pt
#  İndirme başlatılıyor...
